# %% [markdown]
# ![banner.png](data:image/png;base64,...)

# %% [markdown]
# ## O problema do salva-vidas

# %% [markdown]
# Recentemente, um acidente ocorrido na praia do Socorro colocou em evidência um problema até então ignorado.
# Um frequentador escapou com vida de uma situação de afogamento, após ter sido socorrido por um [salva-vidas](https://pt.wikipedia.org/wiki/Salva-vidas).
# O salvamento somente foi possível graças à grande experiência do salva-vidas que soube escolher a trajetória mais curta para alcançar a vítima em tempo hábil.
# Em entrevista logo após o acidente, ele revelou que a escolha da trajetória de salvamento depende de como está a correnteza naquele dia e do ponto de entrada no mar, pois isto pode aumentar ou diminuir o tempo gasto durante seu deslocamento pela praia e durante o trecho realizado a nado.
# Ainda segundo ele, em média, vítimas resgatadas em até três minutos possuem elevada taxa de sobrevivência sem sequelas.
# Neste contexto, devemos nos perguntar: qual é o menor tempo gasto para que um salva-vidas chegue até uma vítima?

# %% [markdown]
# ## Simplificação do problema

# %% [markdown]
# Suponha que a margem do oceano é fixa, definida pela reta $y = 0$ e que uma vítima está pedindo socorro em um ponto $V(x_V, -40)$, enquanto que o salva-vidas está posicionado em $S(x_S, 30)$.

# %% [markdown]
# Suponha ainda que o salva-vidas é capaz de correr na praia a uma velocidade de [$12{,}5$ m/s](https://pt.wikipedia.org/wiki/Usain_Bolt), enquanto que no mar sua velocidade de deslocamento a nado é de [$2{,}67$ m/s](https://pt.wikipedia.org/wiki/Michael_Phelps).

# %% [markdown]
# ## Tarefas

# %% [markdown]
# _(a) Encontre uma função $T$ que meça o tempo total gasto pelo salva-vidas até chegar ao banhista, dependendo apenas do ponto de entrada $P(x,0)$ no mar. \[Dica: escreva a expressão obtida usando LaTeX: https://app.mettzer.com/latex \]_

# %% [markdown]
# *Digite a expressão obtida aqui*

# %% [markdown]
# _(b) Dados $x_V = 0$ e $x_S = 80$, implemente a função $T$ em Python abaixo._

# %%
# Digite seu código aqui

# %% [markdown]
# _(c) Agora, utilize o pacote [matplotlib](https://www.comp.uems.br/~ojacques/NumericPython/BasicoMatPlotLib.pdf) para traçar o gráfico da função implementada._

# %%
# Digite seu código aqui

# %% [markdown]
# _(d) Utilize o método de Newton para determinar o tempo mínimo gasto pelo salva-vidas na trajetória até o banhista._

# %%
# Digite seu código aqui

# %% [markdown]
# ## Saiba mais

# %% [markdown]
# * O problema do salva-vidas é uma velha conhecida aplicação do cálculo, intimamente relacionada com a [lei de refração de Snell](https://pt.wikipedia.org/wiki/Lei_de_Snell).

# %% [markdown]
# * O modelo pode ficar ainda mais realista adicionando novas variáveis, como [a profundidade onde a vítima se encontra](https://www.youtube.com/watch?v=baPiya1CqU0), corrente, etc.

# %% [markdown]
# *Última atualização: 13 de abril de 2023*
