# %% [markdown]
# ![Captura%20de%20tela%20em%202023-09-13%2015-08-50.png](attachment:Captura%20de%20tela%20em%202023-09-13%2015-08-50.png)

# %% [markdown]
# ### **Nome:** _(digite aqui seu nome)_

# %% [markdown]
# **Questão 10.** Seja $\mathbf{A}=\left[a_{ij}\right]$ uma matriz $n \times n$ com $n = 1000$ definida por:

# %% [markdown]
# $$
# a_{ij} =
# \begin{cases}
# i\text{,} & \text{se $i = j$}\\[6pt]
# \frac{1}{2}\text{,} & \text{se $i = j + 1$ ou $j = i + 1$}\\[6pt]
# \frac{1}{2}\text{,} & \text{se $i = j + 2$ ou $j = i + 2$}\\[6pt]
# 0\text{,} & \text{caso contrário}
# \end{cases}
# $$

# %% [markdown]
# (a) Construa a matriz $\mathbf{A}$ usando um arranjo da NumPy.

# %%
# digite seu código aqui.

# %% [markdown]
# (b) Utilize a função `spy` da Matplotlib para visualizar a matriz $\mathbf{A}$.
# \[Dica: consulte a página https://matplotlib.org/stable/gallery/images_contours_and_fields/spy_demos.html\]

# %%
# digite seu código aqui.

# %% [markdown]
# (c) Defina $\mathbf{x}_e$ como sendo o vetor cujas componentes são todas iguais a 1.
# Calcule $\mathbf{b} = \mathbf{A}\mathbf{x}_e$ e resolva o sistema $\mathbf{A}\mathbf{x} = \mathbf{b}$ usando: (i) decomposição LU sem pivotamento, (ii) decomposição LU com pivotamento simples, (iii) decomposição LU com pivotamento parcial escalado, (iv) decomposição de Cholesky, (v) método de Jacobi e (vi) método de Gauss-Seidel.

# %%
# %%time
# (i) decomposição LU sem pivotamento

# %%
# %%time
# (ii) decomposição LU com pivotamento parcial simples

# %%
# %%time
# (iii) decomposição LU com pivotamento parcial escalado

# %%
# %%time
# (iv) decomposição de Cholesky

# %%
# %%time
# (v) método de Jacobi

# %%
# %%time
# (vi) método de Gauss-Seidel

# %% [markdown]
# (d) Calcule os erros relativos usando a norma $\|\cdot\|_2$.
# \[Dica: utilize a função `norm` do pacote `linalg` da NumPy.\]

# %%
# digite seu código aqui.

# %% [markdown]
# (e) Qual método se saiu melhor considerando a relação tempo $\times$ precisão?

# %% [markdown]
# *Digite sua resposta aqui*
